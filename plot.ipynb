# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('diabetic_data.csv', index_col=0, na_values="?")
newdf = df.copy()
# Out:
# /var/folders/_0/jpz85s0964z48by8xyv_gccw0000gn/T/ipykernel_55506/2501423488.py:5: DtypeWarning: Columns (0: medical_specialty) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('diabetic_data.csv', index_col=0, na_values="?")

# %%
ages = newdf["age"]
plt.hist(ages, bins=20)
plt.xlabel("Age")
plt.ylabel("Quantity")
plt.legend()
plt.show()
# Out:
# /var/folders/_0/jpz85s0964z48by8xyv_gccw0000gn/T/ipykernel_55506/3769385018.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
race = newdf["race"]
plt.hist(ages, bins=20)
plt.xlabel("Age")
plt.ylabel("Quantity")
plt.legend()
plt.show()
# Out:
# /var/folders/_0/jpz85s0964z48by8xyv_gccw0000gn/T/ipykernel_55506/56436961.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import os
print(os.listdir())

df = pd.read_csv('diabetic_data.csv')
print(df['readmitted'].value_counts())
# Out:
# ['projekt.py', 'IDS_mapping.csv', 'plot.ipynb', 'diabetic_data.csv', 'test_github.csv', 'train.csv', '.git']
# readmitted
# NO     54864
# >30    35545
# <30    11357
# Name: count, dtype: int64

# %%
# 1. Ladda data (ersätt 'data.csv' med din fil)
df = pd.read_csv('diabetic_data.csv')

# Lista på alla medicinkolumner (från din header)
medication_cols = [
    'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 
    'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 
    'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 
    'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 
    'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone'
]

# Vi vill se hur medicinen korrelerar med om man blev återinskriven (readmitted)
target = 'readmitted'

# Loopa igenom varje medicin och skapa ett stapeldiagram
for med in medication_cols:
    # Kontrollera om medicinen faktiskt har mer än ett värde (vissa kan vara 'No' för alla)
    if df[med].nunique() > 1:
        plt.figure(figsize=(8, 5))
        
        # Skapa en korstabell mellan medicinen och återinskrivning
        ct = pd.crosstab(df[med], df[target], normalize='index')
        
        # Plotta som ett staplat stapeldiagram
        ct.plot(kind='bar', stacked=True, alpha=0.8)
        
        plt.title(f"Inverkan av {med} på {target}")
        plt.xlabel(f"Dosering/Status för {med}")
        plt.ylabel("Andel patienter")
        plt.legend(title="Readmitted", loc='upper right')
        plt.xticks(rotation=0)
        plt.show()
    else:
        print(f"Hoppar över {med}: Innehåller endast ett värde ({df[med].unique()[0]})")
# Out:
# Hoppar över examide: Innehåller endast ett värde (No)
# Hoppar över citoglipton: Innehåller endast ett värde (No)

# %%
df = pd.read_csv('diabetic_data.csv')
readmitted = df.columns[48]
read_labels = {'NO': 0, '>30': 1, '<30': 2}
df['readmitted'] = df['readmitted'].replace({'NO': 0, '>30': 1, '<30': 2})

plt.hist(df['readmitted'], bins = 20)
plt.title("Plot over the readmitted")
plt.xlim(0,2)
plt.xlabel("Readmitted")
plt.ylabel("Quantity")
plt.show()

# %%
# Time in hospital
df = pd.read_csv('diabetic_data.csv', index_col=0, na_values="?")
newdf = df.copy()

time_in_hos = newdf['time_in_hospital']
bins = np.arange(time_in_hos.min() - 0.5, time_in_hos.max() + 1.5, 1)
plt.hist(time_in_hos, bins=bins)
plt.title("Time in hospital")
plt.xticks(range(int(time_in_hos.min()), int(time_in_hos.max()) + 1))
plt.xlabel("Time")
plt.ylabel("Quantity")
plt.show()
# Out:
# /var/folders/_0/jpz85s0964z48by8xyv_gccw0000gn/T/ipykernel_55506/3612512821.py:2: DtypeWarning: Columns (0: medical_specialty) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('diabetic_data.csv', index_col=0, na_values="?")

# %%
race_counts = newdf['race'].value_counts()
race_counts.index = race_counts.index.fillna('Missing')

race_counts.plot(kind='bar')

plt.title("Race Distribution")
plt.xlabel("Race")
plt.ylabel("Quantity")
plt.xticks(rotation=45) # Rotates labels so they don't overlap
plt.tight_layout()       # Ensures labels aren't cut off

plt.show()

# %%
gender = newdf['gender'].value_counts(dropna=False)

gender = gender.rename(index={"Unknown/Invalid": "Unknown", None: "Unknown"})

gender.plot(kind='bar')

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Quantity")
# plt.xticks(rotation=45) # Rotates labels so they don't overlap
# plt.tight_layout()       # Ensures labels aren't cut off

plt.show()

# %%
gender = newdf['medical_specialty'].value_counts(dropna=False)

gender = gender.rename(index={"Unknown/Invalid": "Unknown", None: "Unknown"})

gender.plot(kind='bar')

plt.title("Medical Specialty of Admission Doctor")
plt.xlabel("Specialty")
plt.ylabel("Quantity")
# plt.xticks(rotation=45) # Rotates labels so they don't overlap
# plt.tight_layout()       # Ensures labels aren't cut off

plt.show()
